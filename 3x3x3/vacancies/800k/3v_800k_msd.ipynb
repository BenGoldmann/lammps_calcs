# %% [markdown]
# # Na MSD

# %%
#Set number of Na atoms, timesteps and extract lines with Na

step_count = []
na = []

with open('long.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('long.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'Na ' in line:
        na.append(line)

steps = len(step_count)
na_atoms = int(len(na) / len(step_count))

#Sort out coordinates by dimension        
        
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
na_coords_z = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, steps * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, steps):
        na_coords_x[n].append(float(na_coords_split[n][i][1]))
    for i in range(0, steps):
        na_coords_y[n].append(float(na_coords_split[n][i][2]))
    for i in range(0, steps):
        na_coords_z[n].append(float(na_coords_split[n][i][3]))

#Create list within list with cumulative msd for each Na atom        
        
na_msd = [[] for x in range(0, na_atoms)]

for n in range(0, na_atoms):
    initial = 0
    for t in range(0, (steps-1)):
        step = (na_coords_x[n][t+1] - na_coords_x[n][t])**2 + (na_coords_y[n][t+1] - na_coords_y[n][t])**2 + (na_coords_z[n][t+1] - na_coords_z[n][t])**2
        total = initial + step
        na_msd[n].append(total)
        initial = total

#Create list with cumulative msd for all Na atoms         
        
na_total_msd = []

for t in range(0, (steps-1)):
    initial = 0
    for n in range (0, na_atoms):
        msdt = na_msd[n][t] + initial
        initial = msdt
    na_total_msd.append(msdt)

#Create list with cumulative msd for a single Na atom on average    
    
na_mean_msd = []

for i in na_total_msd:
    na_mean_msd.append(i/na_atoms)

# %% [markdown]
# # O MSD

# %%
#Set number of O atoms, timesteps and extract lines with O

step_count = []
o = []

with open('long.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('long.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'Cl ' in line: #Mixed up O and Cl labels
        o.append(line)

steps = len(step_count)
o_atoms = int(len(o) / len(step_count))

#Sort out coordinates by dimension  

o_coords = [[] for x in range(0, o_atoms)]
o_coords_split = [[] for x in range(0, o_atoms)]
o_coords_x = [[] for x in range(0, o_atoms)]
o_coords_y = [[] for x in range(0, o_atoms)]
o_coords_z = [[] for x in range(0, o_atoms)]
    
for n in range(0, o_atoms):
    for i in range (n, steps * o_atoms, o_atoms):
        o_coords[n].append(o[i])
    for i in o_coords[n]:
        o_coords_split[n].append(i.split())
    for i in range(0, steps):
        o_coords_x[n].append(float(o_coords_split[n][i][1]))
    for i in range(0, steps):
        o_coords_y[n].append(float(o_coords_split[n][i][2]))
    for i in range(0, steps):
        o_coords_z[n].append(float(o_coords_split[n][i][3]))

#Create list within list with cumulative msd for each O atom         
        
o_msd = [[] for x in range(0, o_atoms)]

for n in range(0, o_atoms):
    initial = 0
    for t in range(0, (steps-1)):
        step = (o_coords_x[n][t+1] - o_coords_x[n][t])**2 + (o_coords_y[n][t+1] - o_coords_y[n][t])**2 + (o_coords_z[n][t+1] - o_coords_z[n][t])**2
        total = initial + step
        o_msd[n].append(total)
        initial = total

#Create list with cumulative msd for all O atoms        
        
o_total_msd = []

for t in range(0, (steps-1)):
    initial = 0
    for n in range (0, o_atoms):
        msdt = o_msd[n][t] + initial
        initial = msdt
    o_total_msd.append(msdt)

#Create list with cumulative msd for a single O atom on average      
    
o_mean_msd = []

for i in o_total_msd:
    o_mean_msd.append(i/o_atoms)

# %% [markdown]
# # Cl MSD

# %%
#Set number of Cl atoms, timesteps and extract lines with Cl

step_count = []
cl = []

with open('long.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        step_count.append(line)

with open('long.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'O ' in line: #Mixed up O and Cl labels
        cl.append(line)

steps = len(step_count)
cl_atoms = int(len(cl) / len(step_count))

#Sort out coordinates by dimension         
        
cl_coords = [[] for x in range(0, cl_atoms)]
cl_coords_split = [[] for x in range(0, cl_atoms)]
cl_coords_x = [[] for x in range(0, cl_atoms)]
cl_coords_y = [[] for x in range(0, cl_atoms)]
cl_coords_z = [[] for x in range(0, cl_atoms)]
    
for n in range(0, cl_atoms):
    for i in range (n, steps * cl_atoms, cl_atoms):
        cl_coords[n].append(cl[i])
    for i in cl_coords[n]:
        cl_coords_split[n].append(i.split())
    for i in range(0, steps):
        cl_coords_x[n].append(float(cl_coords_split[n][i][1]))
    for i in range(0, steps):
        cl_coords_y[n].append(float(cl_coords_split[n][i][2]))
    for i in range(0, steps):
        cl_coords_z[n].append(float(cl_coords_split[n][i][3]))

#Create list within list with cumulative msd for each Cl atom        
        
cl_msd = [[] for x in range(0, cl_atoms)]

for n in range(0, cl_atoms):
    initial = 0
    for t in range(0, (steps-1)):
        step = (cl_coords_x[n][t+1] - cl_coords_x[n][t])**2 + (cl_coords_y[n][t+1] - cl_coords_y[n][t])**2 + (cl_coords_z[n][t+1] - cl_coords_z[n][t])**2
        total = initial + step
        cl_msd[n].append(total)
        initial = total

#Create list with cumulative msd for all Cl atoms         
        
cl_total_msd = []

for t in range(0, (steps-1)):
    initial = 0
    for n in range (0, cl_atoms):
        msdt = cl_msd[n][t] + initial
        initial = msdt
    cl_total_msd.append(msdt)

#Create list with cumulative msd for a single Cl atom on average      
    
cl_mean_msd = []

for i in cl_total_msd:
    cl_mean_msd.append(i/cl_atoms)

# %% [markdown]
# # Plot MSDs

# %%
import matplotlib.pyplot as plt

plt.plot(range(0, 2000), na_mean_msd, color='orange')
plt.plot(range(0, 2000), o_mean_msd, color='red')
plt.plot(range(0, 2000), cl_mean_msd, color='green')
plt.xlabel('time, ps')
plt.ylabel('msd, A')
plt.legend(labels=['Na', 'O', 'Cl'], loc='upper left')
plt.title('MSD in 3x3x3 Na3OCl supercell \n with 3 vacant sites at 800 K over 2000 ps')
plt.savefig('/home/ben/Documents/gulp_calcs/0_summary/3v_800k_msd.jpg', bbox_inches='tight', dpi=500)
