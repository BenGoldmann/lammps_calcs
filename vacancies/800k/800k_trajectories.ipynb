# %%
na_atoms = 78
steps = []
na = []

with open('main_nvt_simulation-trajectory.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        steps.append(line)

with open('main_nvt_simulation-trajectory.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'Na' in line:
        na.append(line)
    
na_coords = [[] for x in range(0, na_atoms)]
na_coords_split = [[] for x in range(0, na_atoms)]
na_coords_x = [[] for x in range(0, na_atoms)]
na_coords_y = [[] for x in range(0, na_atoms)]
    
for n in range(0, na_atoms):
    for i in range (n, len(steps) * na_atoms, na_atoms):
        na_coords[n].append(na[i])
    for i in na_coords[n]:
        na_coords_split[n].append(i.split())
    for i in range(0, len(steps)):
        na_coords_x[n].append(float(na_coords_split[n][i][1]))
    for i in range(0, len(steps)):
        na_coords_y[n].append(float(na_coords_split[n][i][2]))

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

#Create figure
fig, ax = plt.subplots()

#Plot paths
for n in range(0, 78):
    plt.plot(na_coords_x[n], na_coords_y[n], color='orange', zorder=-1)

#Add oxide ions
o_x = [2.250500045010, 6.751500000000, 11.252499954990]
o_y = [2.250500045010, 6.751500000000, 11.252499954990]
o_coords = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p in o_coords:
    ax.add_patch(p)

#Add chloride ions   
cl_x = [0, 4.500999954990 ,9.002000045010]
cl_y = [0, 4.500999954990 ,9.002000045010]
cl_coords = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p in cl_coords:
    ax.add_patch(p)    
    
#Make object square   
plt.gca().set_aspect('equal', adjustable='box')

# %%
o_atoms = 27
steps = []
o = []

with open('main_nvt_simulation-trajectory.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        steps.append(line)

with open('main_nvt_simulation-trajectory.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'Cl ' in line:
        o.append(line)
    
o_coords = [[] for x in range(0, o_atoms)]
o_coords_split = [[] for x in range(0, o_atoms)]
o_coords_x = [[] for x in range(0, o_atoms)]
o_coords_y = [[] for x in range(0, o_atoms)]
    
for n in range(0, o_atoms):
    for i in range (n, len(steps) * o_atoms, o_atoms):
        o_coords[n].append(o[i])
    for i in o_coords[n]:
        o_coords_split[n].append(i.split())
    for i in range(0, len(steps)):
        o_coords_x[n].append(float(o_coords_split[n][i][1]))
    for i in range(0, len(steps)):
        o_coords_y[n].append(float(o_coords_split[n][i][2]))

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

#Create figure
fig, ax = plt.subplots()

#Plot paths
for n in range(0, 24):
    plt.plot(o_coords_x[n], o_coords_y[n], color='red', zorder=-1)
    
#Add chloride ions   
cl_x = [0, 4.500999954990 ,9.002000045010]
cl_y = [0, 4.500999954990 ,9.002000045010]
cl_coords = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p in cl_coords:
    ax.add_patch(p) 

#Add sodium ions      
na_x = [2.250500045010, 4.500999954990, 6.751500000000, 9.002000045010, 11.252499954990]
na_y = [2.250500045010, 4.500999954990, 6.751500000000, 9.002000045010, 11.252499954990]
na_coords = []

for i in na_x:
    for j in na_y:
        na_coords.append(patches.Circle((i, j), 0.5, facecolor='orange', edgecolor='black', zorder=-0.5))
    
for p in na_coords:
    ax.add_patch(p)    
    
#Make object square   
plt.gca().set_aspect('equal', adjustable='box')

# %%
cl_atoms = 24
steps = []
cl = []

with open('main_nvt_simulation-trajectory.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'TIMESTEP' in line:
        steps.append(line)

with open('main_nvt_simulation-trajectory.lammpstrj') as file:
    content = file.readlines()
for line in content:
    if 'O ' in line:
        cl.append(line)
    
cl_coords = [[] for x in range(0, cl_atoms)]
cl_coords_split = [[] for x in range(0, cl_atoms)]
cl_coords_x = [[] for x in range(0, cl_atoms)]
cl_coords_y = [[] for x in range(0, cl_atoms)]
    
for n in range(0, cl_atoms):
    for i in range (n, len(steps) * cl_atoms, cl_atoms):
        cl_coords[n].append(cl[i])
    for i in coords[n]:
        cl_coords_split[n].append(i.split())
    for i in range(0, len(steps)):
        cl_coords_x[n].append(float(cl_coords_split[n][i][1]))
    for i in range(0, len(steps)):
        cl_coords_y[n].append(float(cl_coords_split[n][i][2]))

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

#Create figure
fig, ax = plt.subplots()

#Plot paths
for n in range(0, 24):
    plt.plot(cl_coords_x[n], cl_coords_y[n], color='green', zorder=-1)
    
#Add oxide ions
o_x = [2.250500045010, 6.751500000000, 11.252499954990]
o_y = [2.250500045010, 6.751500000000, 11.252499954990]
o_coords = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p in o_coords:
    ax.add_patch(p)

#Add sodium ions      
na_x = [2.250500045010, 4.500999954990, 6.751500000000, 9.002000045010, 11.252499954990]
na_y = [2.250500045010, 4.500999954990, 6.751500000000, 9.002000045010, 11.252499954990]
na_coords = []

for i in na_x:
    for j in na_y:
        na_coords.append(patches.Circle((i, j), 0.5, facecolor='orange', edgecolor='black', zorder=-0.5))
    
for p in na_coords:
    ax.add_patch(p)    
    
#Make object square   
plt.gca().set_aspect('equal', adjustable='box')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

#Create figure
fig, ax = plt.subplots()

#Plot paths
plt.plot(na_coords_x[69][1250:], na_coords_y[69][1250:], color='orange', zorder=-1)

#Add oxide ions
o_x = [2.250500045010, 6.751500000000, 11.252499954990]
o_y = [2.250500045010, 6.751500000000, 11.252499954990]
o_coords = []

for i in o_x:
    for j in o_y:
        o_coords.append(patches.Circle((i, j), 0.5, facecolor='red', edgecolor='black'))
    
for p in o_coords:
    ax.add_patch(p)

#Add chloride ions   
cl_x = [0, 4.500999954990 ,9.002000045010]
cl_y = [0, 4.500999954990 ,9.002000045010]
cl_coords = []

for i in cl_x:
    for j in cl_y:
        cl_coords.append(patches.Circle((i, j), 0.5, facecolor='green', edgecolor='black'))
    
for p in cl_coords:
    ax.add_patch(p)    
    
#Make object square   
plt.gca().set_aspect('equal', adjustable='box')
